# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    # Connect to MySQL
    conn = mysql.connector.connect(
        host="localhost",
        user="root",
        password="n",
        database="libraryDb"
    )
    
    if conn.is_connected():
        print("✅ Database connected successfully!")
        
        # Fetch data using pandas
        query = "SELECT * FROM books"
        df = pd.read_sql(query, conn)
        print(df.head())

except Error as err:
    print(f"⚠️ Database Error: {err}")

finally:
    if 'conn' in locals() and conn.is_connected():
        conn.close()
        print("🔒 Connection closed.")
# Out:
# ✅ Database connected successfully!
#    BookId                Title            Author  price        Genre  \
# 0     101   Python Programming  Guido van Rossum  499.0    Education
# 1     102           Python 101          John Doe  500.0  Programming
# 2     103    Rich Dad Poor Dad   Robert Kiyosaki  600.0      Finance
# 3     104        Atomic Habits       James Clear  800.0    Self Help
# 4     105  Data Science Basics          Mark Lee  900.0    Education
#
#       Status
# 0  Available
# 1     Issued
# 2  Available
# 3  Available
# 4     Issued
# 🔒 Connection closed.
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12588\942012351.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
